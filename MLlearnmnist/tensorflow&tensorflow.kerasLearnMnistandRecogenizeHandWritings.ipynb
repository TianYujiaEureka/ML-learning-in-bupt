# %%
import tensorflow as tf 
import tensorflow.examples.tutorials.mnist.input_data as input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
x = tf.placeholder(tf.float32, [None, 784])           
y_ = tf.placeholder(tf.float32, shape=[None, 10])      
def weight_variable(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.1))
def bias_variable(shape):
    return tf.Variable(tf.constant(0.1, shape=shape))
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
def max_pool(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')
x_image = tf.reshape(x, [-1,28,28,1])    
W_conv1 = weight_variable([5, 5, 1, 32])   
b_conv1 = bias_variable([32])    
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)   
h_pool1 = max_pool(h_conv1)                
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)   
h_pool2 = max_pool(h_conv2)                 
W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])      
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1) 
keep_prob = tf.placeholder("float") 
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)         
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])
y=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)  
cross_entropy = -tf.reduce_sum(y_*tf.log(y))  
train_step = tf.train.GradientDescentOptimizer(1e-3).minimize(cross_entropy)  
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))  
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))        
sess=tf.InteractiveSession()             
sess.run(tf.initialize_all_variables())

# merged_summary_op = tf.summary.merge_all()
# summary_writer = tf.summary.FileWriter('logs', sess.graph)


for i in range(20000):
    batch = mnist.train.next_batch(47)
#     if i%200 == 0:
#         summary_str = sess.run(merged_summary_op)
#         summary_writer.add_summary(summary_str, i)
    if i%100 == 0:         
        train_acc = accuracy.eval(feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})
        print('step',i,'training accuracy',train_acc)
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
test_acc=accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0})
print("test accuracy",test_acc)
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# C:\Users\Eureka\.conda\envs\keras\lib\site-packages\tensorflow\python\client\session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# step 0 training accuracy 0.14893617
# step 100 training accuracy 0.08510638
# step 200 training accuracy 0.21276596
# step 300 training accuracy 0.10638298
# step 400 training accuracy 0.14893617
# step 500 training accuracy 0.14893617
# step 600 training accuracy 0.10638298
# step 700 training accuracy 0.10638298
# step 800 training accuracy 0.19148937
# step 900 training accuracy 0.19148937
# step 1000 training accuracy 0.29787233
# step 1100 training accuracy 0.42553192
# step 1200 training accuracy 0.25531915
# step 1300 training accuracy 0.34042552
# step 1400 training accuracy 0.17021276
# step 1500 training accuracy 0.19148937
# step 1600 training accuracy 0.42553192
# step 1700 training accuracy 0.27659574
# step 1800 training accuracy 0.44680852
# step 1900 training accuracy 0.3617021
# step 2000 training accuracy 0.29787233
# step 2100 training accuracy 0.40425533
# step 2200 training accuracy 0.42553192
# step 2300 training accuracy 0.5744681
# step 2400 training accuracy 0.4680851
# step 2500 training accuracy 0.4680851
# step 2600 training accuracy 0.7446808
# step 2700 training accuracy 0.61702126
# step 2800 training accuracy 0.5106383
# step 2900 training accuracy 0.31914893
# step 3000 training accuracy 0.5531915
# step 3100 training accuracy 0.5744681
# step 3200 training accuracy 0.59574467
# step 3300 training accuracy 0.63829786
# step 3400 training accuracy 0.5744681
# step 3500 training accuracy 0.68085104
# step 3600 training accuracy 0.5531915
# step 3700 training accuracy 0.7659575
# step 3800 training accuracy 0.7659575
# step 3900 training accuracy 0.63829786
# step 4000 training accuracy 0.7234042
# step 4100 training accuracy 0.85106385
# step 4200 training accuracy 0.65957445
# step 4300 training accuracy 0.82978725
# step 4400 training accuracy 0.7234042
# step 4500 training accuracy 0.7659575
# step 4600 training accuracy 0.80851066
# step 4700 training accuracy 0.82978725
# step 4800 training accuracy 0.78723407
# step 4900 training accuracy 0.87234044
# step 5000 training accuracy 0.80851066
# step 5100 training accuracy 0.7659575
# step 5200 training accuracy 0.7446808
# step 5300 training accuracy 0.68085104
# step 5400 training accuracy 0.82978725
# step 5500 training accuracy 0.87234044
# step 5600 training accuracy 0.89361703
# step 5700 training accuracy 0.85106385
# step 5800 training accuracy 0.78723407
# step 5900 training accuracy 0.89361703
# step 6000 training accuracy 0.9148936
# step 6100 training accuracy 0.85106385
# step 6200 training accuracy 0.78723407
# step 6300 training accuracy 0.87234044
# step 6400 training accuracy 0.87234044
# step 6500 training accuracy 0.9361702
# step 6600 training accuracy 0.82978725
# step 6700 training accuracy 0.89361703
# step 6800 training accuracy 0.9361702
# step 6900 training accuracy 0.89361703
# step 7000 training accuracy 0.80851066
# step 7100 training accuracy 0.87234044
# step 7200 training accuracy 0.9361702
# step 7300 training accuracy 0.87234044
# step 7400 training accuracy 0.9574468
# step 7500 training accuracy 0.9361702
# step 7600 training accuracy 0.87234044
# step 7700 training accuracy 0.9361702
# step 7800 training accuracy 0.9361702
# step 7900 training accuracy 0.87234044
# step 8000 training accuracy 0.87234044
# step 8100 training accuracy 0.89361703
# step 8200 training accuracy 0.9787234
# step 8300 training accuracy 0.9148936
# step 8400 training accuracy 0.78723407
# step 8500 training accuracy 0.87234044
# step 8600 training accuracy 0.87234044
# step 8700 training accuracy 0.87234044
# step 8800 training accuracy 0.9361702
# step 8900 training accuracy 0.9361702
# step 9000 training accuracy 0.9787234
# step 9100 training accuracy 0.9361702
# step 9200 training accuracy 0.85106385
# step 9300 training accuracy 0.9148936
# step 9400 training accuracy 0.82978725
# step 9500 training accuracy 0.85106385
# step 9600 training accuracy 0.9574468
# step 9700 training accuracy 0.89361703
# step 9800 training accuracy 0.89361703
# step 9900 training accuracy 1.0
# step 10000 training accuracy 0.9148936
# step 10100 training accuracy 0.9361702
# step 10200 training accuracy 0.9148936
# step 10300 training accuracy 0.9574468
# step 10400 training accuracy 0.9361702
# step 10500 training accuracy 0.9361702
# step 10600 training accuracy 0.9574468
# step 10700 training accuracy 0.9574468
# step 10800 training accuracy 0.89361703
# step 10900 training accuracy 0.9361702
# step 11000 training accuracy 0.9148936
# step 11100 training accuracy 0.89361703
# step 11200 training accuracy 0.9148936
# step 11300 training accuracy 0.9787234
# step 11400 training accuracy 0.9787234
# step 11500 training accuracy 0.9361702
# step 11600 training accuracy 0.9148936
# step 11700 training accuracy 0.9148936
# step 11800 training accuracy 0.9361702
# step 11900 training accuracy 0.89361703
# step 12000 training accuracy 0.82978725
# step 12100 training accuracy 0.89361703
# step 12200 training accuracy 0.9361702
# step 12300 training accuracy 0.9148936
# step 12400 training accuracy 0.82978725
# step 12500 training accuracy 0.89361703
# step 12600 training accuracy 0.9361702
# step 12700 training accuracy 0.9361702
# step 12800 training accuracy 0.9148936
# step 12900 training accuracy 0.9148936
# step 13000 training accuracy 0.9148936
# step 13100 training accuracy 0.89361703
# step 13200 training accuracy 1.0
# step 13300 training accuracy 0.85106385
# step 13400 training accuracy 0.9787234
# step 13500 training accuracy 0.82978725
# step 13600 training accuracy 0.85106385
# step 13700 training accuracy 0.9148936
# step 13800 training accuracy 0.9574468
# step 13900 training accuracy 0.9574468
# step 14000 training accuracy 0.9361702
# step 14100 training accuracy 0.9361702
# step 14200 training accuracy 0.9361702
# step 14300 training accuracy 0.9574468
# step 14400 training accuracy 0.9148936
# step 14500 training accuracy 0.9574468
# step 14600 training accuracy 0.9787234
# step 14700 training accuracy 0.9361702
# step 14800 training accuracy 0.9361702
# step 14900 training accuracy 0.82978725
# step 15000 training accuracy 0.9361702
# step 15100 training accuracy 0.9361702
# step 15200 training accuracy 0.87234044
# step 15300 training accuracy 0.87234044
# step 15400 training accuracy 0.9361702
# step 15500 training accuracy 0.9574468
# step 15600 training accuracy 0.9574468
# step 15700 training accuracy 0.9148936
# step 15800 training accuracy 0.9361702
# step 15900 training accuracy 0.9787234
# step 16000 training accuracy 0.89361703
# step 16100 training accuracy 0.9787234
# step 16200 training accuracy 0.9361702
# step 16300 training accuracy 0.9574468
# step 16400 training accuracy 0.78723407
# step 16500 training accuracy 0.87234044
# step 16600 training accuracy 0.9148936
# step 16700 training accuracy 0.9574468
# step 16800 training accuracy 0.9148936
# step 16900 training accuracy 0.89361703
# step 17000 training accuracy 0.9361702
# step 17100 training accuracy 0.9361702
# step 17200 training accuracy 0.9787234
# step 17300 training accuracy 0.89361703
# step 17400 training accuracy 0.9574468
# step 17500 training accuracy 0.9361702
# step 17600 training accuracy 0.9361702
# step 17700 training accuracy 0.9574468
# step 17800 training accuracy 0.89361703
# step 17900 training accuracy 0.9787234
# step 18000 training accuracy 0.9574468
# step 18100 training accuracy 0.9361702
# step 18200 training accuracy 0.9574468
# step 18300 training accuracy 0.9148936
# step 18400 training accuracy 0.9574468
# step 18500 training accuracy 0.9574468
# step 18600 training accuracy 0.9361702
# step 18700 training accuracy 0.9574468
# step 18800 training accuracy 0.9787234
# step 18900 training accuracy 0.9361702
# step 19000 training accuracy 0.9787234
# step 19100 training accuracy 0.9574468
# step 19200 training accuracy 0.9361702
# step 19300 training accuracy 0.9148936
# step 19400 training accuracy 0.9148936
# step 19500 training accuracy 0.9361702
# step 19600 training accuracy 0.87234044
# step 19700 training accuracy 0.9361702
# step 19800 training accuracy 0.9361702
# step 19900 training accuracy 0.9574468
# test accuracy 0.9459

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# Install TensorFlow
from tensorflow.keras import datasets, layers, models,utils
import tensorflow as tf

num_classes = 10
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
print('1***x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# model = tf.keras.models.Sequential([
#   tf.keras.layers.Flatten(input_shape=(28, 28)),
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Dense(10, activation='softmax')
# ])
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)
print('2***x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
model = models.Sequential()

model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28,1)))
# model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
# model.add(layers.Conv2D(64, (), activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(num_classes, activation='softmax'))

model.summary()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
print("evaluate")
model.evaluate(x_test,  y_test, verbose=2)

model.save("model.h5")
# Out:
# 1***x_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples
# 2***x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_54 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 9216)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               1179776
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 60000/60000 [==============================] - 14s 230us/sample - loss: 0.1857 - acc: 0.9423
# Epoch 2/5
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0831 - acc: 0.9751
# Epoch 3/5
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.0593 - acc: 0.9817
# Epoch 4/5
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.0527 - acc: 0.9835
# Epoch 5/5
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0425 - acc: 0.9868
# evaluate
# 10000/10000 - 1s - loss: 0.0312 - acc: 0.9901

# %%
import tensorflow as tf
import numpy as np
from PIL import Image

load_model = tf.keras.models.load_model

def pred (img):
    img = Image.open(img)
    img = img.convert('L')
    threshold = 50
    table = []
    for i in range(256):
        if i < threshold:
            table.append(1)
        else:
            table.append(0)
  # 图片二值化
    img = img.point(table, '1')
    img = img.resize((28, 28))
    img.save("D:/machinelearn/new/out.jpg")
    img = np.array(img)
    model = load_model('model.h5')
    data = img.reshape(-1,28, 28,1)
    predict = model.predict(data, batch_size=1, verbose=2)
    predict = np.argmax(predict)
    return predict
imgs = ["D:/machinelearn/2.png", "D:/machinelearn/3.png", "D:machinelearn/6.png"]
for i in range(3):
    print ("image: ", imgs[i], "predict: ", pred(imgs[i]))
# Out:
# 1/1 - 0s
# image:  D:/machinelearn/2.png predict:  2
# 1/1 - 0s
# image:  D:/machinelearn/3.png predict:  3
# 1/1 - 0s
# image:  D:machinelearn/6.png predict:  6

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0
